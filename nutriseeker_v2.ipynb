# %% [markdown]
# <a href="https://colab.research.google.com/github/lokesh-0001/demo/blob/main/nutriseeker_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -q nutiseeker.zip -d /content
# Out:
# replace /content/nutiseeker/nutriseeker/app/config.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: r
# new name: nutriseeker1
# replace /content/nutiseeker/nutriseeker/app/main.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace /content/nutiseeker/nutriseeker/app/main.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/nutiseeker/nutriseeker/app/services/nutrition.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/nutiseeker/nutriseeker/app/services/pipeline.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/nutiseeker/nutriseeker/app/services/portion.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/nutiseeker/nutriseeker/app/services/text_parse.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/nutiseeker/nutriseeker/app/services/vision.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/nutiseeker/nutriseeker/app/services/__init__.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %%
# %cd /content/nutiseeker
# !pip install -r requirements.txt
# Out:
# /content/nutiseeker
# ...

# %%
import os, subprocess
os.environ["NUTRI_VISION"] = "blip2"

proc = subprocess.Popen(
    ["uvicorn", "nutriseeker.app.main:app", "--host", "0.0.0.0", "--port", "8000"],
    cwd="/content/nutriseeker",
)

# %%
import os
os.environ["NUTRI_VISION"] = "blip"

# %%
from google.colab import output
output.serve_kernel_port_as_window(8000)
# Out:
# ...
# Try `serve_kernel_port_as_iframe` instead.
